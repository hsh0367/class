# %%
import pandas as pd

# %% [markdown]
# ## 데이터셋 읽기

# %%
train = pd.read_csv('train.tsv', sep='\t', index_col='PhraseId')
print(train.shape)
train.head(3)
# Out:
# (156060, 3)
#           SentenceId                                             Phrase  \
# PhraseId
# 1                  1  A series of escapades demonstrating the adage ...
# 2                  1  A series of escapades demonstrating the adage ...
# 3                  1                                           A series
#
#           Sentiment
# PhraseId
# 1                 1
# 2                 2
# 3                 2

# %%
test = pd.read_csv('test.tsv', sep='\t', index_col='PhraseId')
print(test.shape)
test.head
# Out:
# (66292, 2)
# <bound method NDFrame.head of           SentenceId                                             Phrase
# PhraseId
# 156061          8545  An intermittently pleasing but mostly routine ...
# 156062          8545  An intermittently pleasing but mostly routine ...
# 156063          8545                                                 An
# 156064          8545  intermittently pleasing but mostly routine effort
# 156065          8545         intermittently pleasing but mostly routine
# 156066          8545                        intermittently pleasing but
# 156067          8545                            intermittently pleasing
# 156068          8545                                     intermittently
# 156069          8545                                           pleasing
# 156070          8545                                                but
# 156071          8545                                     mostly routine
# 156072          8545                                             mostly
# 156073          8545                                            routine
# 156074          8545                                             effort
# 156075          8545                                                  .
# 156076          8546  Kidman is really the only thing that 's worth ...
# 156077          8546                                             Kidman
# 156078          8546  is really the only thing that 's worth watchin...
# 156079          8546  is really the only thing that 's worth watchin...
# 156080          8546                                          is really
# 156081          8546                                                 is
# 156082          8546                                             really
# 156083          8546  the only thing that 's worth watching in Birth...
# 156084          8546                                     the only thing
# 156085          8546                                                the
# 156086          8546                                         only thing
# 156087          8546                                               only
# 156088          8546                                              thing
# 156089          8546  that 's worth watching in Birthday Girl , a fi...
# 156090          8546                                               that
# ...              ...                                                ...
# 222323         11853                                          organized
# 222324         11853                                         efficiency
# 222325         11853                                numerous flashbacks
# 222326         11853                         a constant edge of tension
# 222327         11853                                    a constant edge
# 222328         11853                                      constant edge
# 222329         11853  , Miller 's film is one of 2002 's involvingly...
# 222330         11853  Miller 's film is one of 2002 's involvingly a...
# 222331         11853                                     Miller 's film
# 222332         11853    is one of 2002 's involvingly adult surprises .
# 222333         11853      is one of 2002 's involvingly adult surprises
# 222334         11853         one of 2002 's involvingly adult surprises
# 222335         11853             of 2002 's involvingly adult surprises
# 222336         11853                2002 's involvingly adult surprises
# 222337         11853                                            2002 's
# 222338         11853                        involvingly adult surprises
# 222339         11853                                        involvingly
# 222340         11853                                    adult surprises
# 222341         11854            They should have called it Gutterball .
# 222342         11854                 should have called it Gutterball .
# 222343         11854                   should have called it Gutterball
# 222344         11854                          have called it Gutterball
# 222345         11854                               called it Gutterball
# 222346         11854                                      it Gutterball
# 222347         11854                                         Gutterball
# 222348         11855             A long-winded , predictable scenario .
# 222349         11855               A long-winded , predictable scenario
# 222350         11855                                    A long-winded ,
# 222351         11855                                      A long-winded
# 222352         11855                               predictable scenario
#
# [66292 rows x 2 columns]>

# %% [markdown]
# ## 전처리

# %% [markdown]
# ## clean text

# %%
def clean_text(word):
    word = word.replace("disappointments", "disappointment")
    word = word.replace("n't", "not")
    return word 

train["Phrase"] = train["Phrase"].apply(clean_text)

# %%
train[train["Phrase"].str.contains("n't")]
# Out:
# Empty DataFrame
# Columns: [SentenceId, Phrase, Sentiment]
# Index: []

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_features = 50000, lowercase=False, ngram_range=(1,3))
vectorizer
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=False, max_df=1.0, max_features=50000, min_df=1,
#         ngram_range=(1, 3), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
vectorizer.fit(train["Phrase"])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=False, max_df=1.0, max_features=50000, min_df=1,
#         ngram_range=(1, 3), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
X_train = vectorizer.transform(train["Phrase"])
print(X_train.shape)

X_train
columns = vectorizer.get_feature_names()
train_vector = pd.DataFrame(X_train.toarray(), columns= columns)
# Out:
# (156060, 50000)

# %%
columns
# Out:
# ['000',
#  '000 Leagues',
#  '000 Leagues Under',
#  '000 times',
#  '10',
#  '10 000',
#  '10 000 times',
#  '10 minutes',
#  '10 minutes prior',
#  '10 or',
#  '10 or 15',
#  '10 seconds',
#  '10 set',
#  '10 year',
#  '10 year delay',
#  '10 year old',
#  '10 years',
#  '10 years ago',
#  '100',
#  '100 minute',
#  '100 minute running',
#  '100 minutes',
#  '100 years',
#  '101',
#  '101 premise',
#  '101 study',
#  '102',
#  '102 minute',
#  '102 minute infomercial',
#  '103',
#  '103 minute',
#  '103 minute length',
#  '104',
#  '104 minutes',
#  '105',
#  '105 minutes',
#  '105 minutes seem',
#  '10th',
#  '10th grade',
#  '10th grade learning',
#  '11',
#  '11 period',
#  '110',
#  '12',
#  '12 shot',
#  '12 year',
#  '12 year old',
#  '127',
#  '12th',
#  '13',
#  '13 Conversations',
#  '13 months',
#  '13 months and',
#  '13 rating',
#  '13 was',
#  '13 was going',
#  '13th',
#  '13th by',
#  '13th by way',
#  '14',
#  '14 year',
#  '14 year old',
#  '146',
#  '146 minutes',
#  '146 minutes of',
#  '15',
#  '15 minutes',
#  '15 year',
#  '15 years',
#  '15 years old',
#  '16',
#  '163',
#  '163 minutes',
#  '170',
#  '170 minutes',
#  '170 minutes long',
#  '1790',
#  '18',
#  '18 or',
#  '18 or 80',
#  '18 year',
#  '18 year old',
#  '19',
#  '1915',
#  '1915 Armenia',
#  '1920',
#  '1938',
#  '1940s',
#  '1950s',
#  '1952',
#  '1958',
#  '1958 Brooklyn',
#  '1958 Brooklyn stale',
#  '1959',
#  '1959 Godzilla',
#  '1960',
#  '1960 with',
#  '1960 with Peter',
#  '1960s',
#  '1970s',
#  '1971',
#  '1971 musical',
#  '1973',
#  '1973 film',
#  '1973 film The',
#  '1975',
#  '1979',
#  '1980',
#  '1980 biopic',
#  '1980s',
#  '1984',
#  '1984 RRB',
#  '1987',
#  '1989',
#  '1989 Paradiso',
#  '1989 Paradiso will',
#  '1993',
#  '1993 classic',
#  '1995',
#  '1995 Forget',
#  '1995 Forget Paris',
#  '1998',
#  '1999',
#  '1999 RRB',
#  '1999 RRB and',
#  '19th',
#  '19th Century',
#  '19th Century crime',
#  '19th century',
#  '19th century prose',
#  '20',
#  '20 000',
#  '20 000 Leagues',
#  '20 car',
#  '20 centuries',
#  '20 million',
#  '20 minutes',
#  '20 minutes looking',
#  '20 years',
#  '20 years of',
#  '2000',
#  '2000 debut',
#  '2000 debut Shanghai',
#  '2001',
#  '2002',
#  '2002 Sundance',
#  '2002 Sundance Festival',
#  '20th',
#  '20th anniversary',
#  '20th anniversary edition',
#  '20th century',
#  '20th century footnotes',
#  '21',
#  '21 hours',
#  '21st',
#  '21st Century',
#  '21st Century new',
#  '21st century',
#  '21st century reality',
#  '22',
#  '22 glory',
#  '22 year',
#  '22 year old',
#  '24',
#  '2455',
#  '25',
#  '26',
#  '295',
#  '30',
#  '30 minutes',
#  '30 seconds',
#  '30 seconds of',
#  '300',
#  '3000',
#  '3000 guys',
#  '30s',
#  '30s and',
#  '30s and 40s',
#  '3D',
#  '3D goggles',
#  '40',
#  '40s',
#  '451',
#  '48',
#  '48 Hours',
#  '48 Hours LRB',
#  '4Ever',
#  '50',
#  '50 other',
#  '50 other filmmakers',
#  '50 year',
#  '50 year friendship',
#  '50 year old',
#  '500',
#  '50s',
#  '50s flicks',
#  '50s sociology',
#  '51',
#  '51 times',
#  '52',
#  '60',
#  '60s',
#  '65',
#  '65th',
#  '65th class',
#  '65th class reunion',
#  '70s',
#  '70s blaxploitation',
#  '70s blaxploitation shuck',
#  '72',
#  '75',
#  '7th',
#  '7th century',
#  '7th century oral',
#  '80',
#  '80 minute',
#  '80 minutes',
#  '80 minutes from',
#  '800',
#  '80s',
#  '83',
#  '83 minutes',
#  '84',
#  '84 minutes',
#  '85',
#  '86',
#  '86 minutes',
#  '88',
#  '88 minute',
#  '88 minute rip',
#  '89',
#  '89 minutes',
#  '8th',
#  '8th grade',
#  '8th grade boy',
#  '90',
#  '90 minute',
#  '90 minute movie',
#  '90 minutes',
#  '90 minutes of',
#  '90 minutes these',
#  '90 more',
#  '90 more minutes',
#  '90 plus',
#  '90s',
#  '91',
#  '91 minute',
#  '91 minute trailer',
#  '93',
#  '94',
#  '94 minutes',
#  '95',
#  '95 minute',
#  '95 minute commercial',
#  '99',
#  '99 bargain',
#  '99 bargain basement',
#  'ABC',
#  'AIDS',
#  'AIDS subtext',
#  'Aaliyah',
#  'Abagnale',
#  'Abagnale antics',
#  'Abandon',
#  'Abbott',
#  'Abdul',
#  'Abdul Malik',
#  'Abdul Malik Abbott',
#  'Abel',
#  'Abel Ferrara',
#  'Abomination',
#  'About',
#  'About Boy',
#  'About Eve',
#  'About Eve or',
#  'About Her',
#  'About Lily',
#  'About Lily Chou',
#  'About Mary',
#  'About Mary and',
#  'About One',
#  'About One Thing',
#  'About Schmidt',
#  'About Schmidt RRB',
#  'About the',
#  'Abrahams',
#  'Abrahams films',
#  'Academy',
#  'Academy Award',
#  'Academy Award winning',
#  'Academy Awards',
#  'Academy flicks',
#  'Actress',
#  'Adam',
#  'Adam Sandler',
#  'Adam Sandler Chanukah',
#  'Adam Sandler new',
#  'Adam Sandler will',
#  'Adams',
#  'Addams',
#  'Addams Family',
#  'Adrian',
#  'Adrian Lyne',
#  'Adventures',
#  'Adventures of',
#  'Adventures of Direct',
#  'Affleck',
#  'Affleck seem',
#  'Affleck seem downright',
#  'Afghan',
#  'Afghan refugees',
#  'Afghan refugees on',
#  'Afghani',
#  'Afghani refugees',
#  'Afghani refugees who',
#  'African',
#  'African American',
#  'African American professionals',
#  'African Americans',
#  'African Americans because',
#  'African coast',
#  'African empire',
#  'After',
#  'After Next',
#  'After Next to',
#  'Afternoon',
#  'Afternoon with',
#  'Afternoon with cause',
#  'Again',
#  'Age',
#  'Age inspired',
#  'Age inspired good',
#  'Ah',
#  'Ah Na',
#  'Ah yes',
#  'Aid',
#  'Aiello',
#  'Alabama',
#  'Alabama is',
#  'Aladdin',
#  'Alagna',
#  'Alan',
#  'Aldrich',
#  'Alexander',
#  'Alexander Payne',
#  'Alexandre',
#  'Alexandre Dumas',
#  'Alexandre Dumas classic',
#  'Alfred',
#  'Alfred Hitchcock',
#  'Ali',
#  'Ali MacGraw',
#  'Alice',
#  'Alice Krige',
#  'Alice Krige cape',
#  'Aliens',
#  'Aliens and',
#  'Aliens and every',
#  'All',
#  'All About',
#  'All About Eve',
#  'All About Lily',
#  'All Fears',
#  'All Fears starring',
#  'All That',
#  'All That Heaven',
#  'All in',
#  'All in all',
#  'All of',
#  'All of Me',
#  'All the',
#  'All the Queen',
#  'Allen',
#  'Allen RRB',
#  'Allen film',
#  'Allen romantic',
#  'Allen romantic comedies',
#  'Allows',
#  'Allows and',
#  'Almodovar',
#  'Almost',
#  'Alone',
#  'Altar',
#  'Altar Boys',
#  'Although',
#  'Although it',
#  'Altman',
#  'Altman Spike',
#  'Altman Spike Lee',
#  'Altman esque',
#  'Amaro',
#  'Amazing',
#  'Ambrose',
#  'America',
#  'America and',
#  'America history',
#  'America history and',
#  'America indigenous',
#  'America indigenous people',
#  'America sketchy',
#  'America sketchy but',
#  'America winter',
#  'America winter movie',
#  'American',
#  'American Beauty',
#  'American Dream',
#  'American Indians',
#  'American Pie',
#  'American Pie hijinks',
#  'American Pie movies',
#  'American Russian',
#  'American Russian Armageddon',
#  'American action',
#  'American action adventure',
#  'American and',
#  'American and European',
#  'American angst',
#  'American art',
#  'American art house',
#  'American audiences',
#  'American cinema',
#  'American decision',
#  'American decision that',
#  'American director',
#  'American film',
#  'American in',
#  'American in 1979',
#  'American life',
#  'American moviemaking',
#  'American moviemaking ever',
#  'American movies',
#  'American movies of',
#  'American professionals',
#  'American scorn',
#  'American style',
#  'American style of',
#  'American teen',
#  'American teen comedies',
#  'American underground',
#  'American workers',
#  'Americans',
#  'Americans and',
#  'Americans and Brits',
#  'Americans and their',
#  'Americans because',
#  'Americans because of',
#  'Americans to',
#  'Americans to finally',
#  'Amini',
#  'Amir',
#  'Amir Mann',
#  'Amish',
#  'Amish people',
#  'Amish people alive',
#  'Amos',
#  'Amos records',
#  'Amy',
#  'Amy and',
#  'Amy and Changing',
#  'An',
#  'An ambitious',
#  'An empty',
#  'An engrossing',
#  'An enjoyable',
#  'An entertaining',
#  'An old',
#  'An old fashioned',
#  'An uncomfortable',
#  'Analyze',
#  'Analyze That',
#  'Analyze That promised',
#  'Analyze This',
#  'Analyze This LRB',
#  'Analyze This not',
#  'And',
#  'And butterflies',
#  'And butterflies that',
#  'Anderson',
#  'Anderson Magnolia',
#  'Anderson Magnolia and',
#  'Andie',
#  'Angel',
#  'Angel simplicity',
#  'Angela',
#  'Angela Gheorghiu',
#  'Angeles',
#  'Angelina',
#  'Angelina Jolie',
#  'Angelique',
#  'Angels',
#  'Animal',
#  'Animal House',
#  'Animal Planet',
#  'Anna',
#  'Anna Mouglalis',
#  'Anne',
#  'Anne Geddes',
#  'Anne Geddes John',
#  'Anne Rice',
#  'Anne Rice novel',
#  'Anne Sophie',
#  'Anne Sophie Birot',
#  'Annie',
#  'Annie Mary',
#  'Annie Mary but',
#  'Another',
#  'Another Day',
#  'Another Day is',
#  'Anthony',
#  'Anthony Hopkins',
#  'Anthony Hopkins and',
#  'Antitrust',
#  'Antonia',
#  'Antonia can',
#  'Antonia can feel',
#  'Antonia true',
#  'Antonia true emotions',
#  'Antonio',
#  'Antonio Banderas',
#  'Antonio Banderas Lucy',
#  'Antwone',
#  'Antwone Fisher',
#  'Antwone Fisher based',
#  'Antwone Fisher or',
#  'Any',
#  'Anyone',
#  'Anyone who',
#  'Apollo',
#  'Apollo 13',
#  'Apollo 13 was',
#  'Apple',
#  'Apted',
#  'Apted LRB',
#  'Apted LRB Enigma',
#  'Ararat',
#  'Archibald',
#  'Are',
#  'Are we',
#  'Are we there',
#  'Argentine',
#  'Argentine director',
#  'Argentine director Fabian',
#  'Argentine retread',
#  'Argentine retread of',
#  'Argentinian',
#  'Argento',
#  'Argento Hollywood',
#  'Argento Hollywood counterparts',
#  'Armageddon',
#  'Armenia',
#  'Arnie',
#  'Arnie musclefest',
#  'Arnold',
#  'Arnold Schwarzenegger',
#  'Arnold Schwarzenegger Jean',
#  'Art',
#  'Arthur',
#  'As',
#  'As an',
#  'As the',
#  'Ash',
#  'Ash Wednesday',
#  'Ash Wednesday is',
#  'Ashley',
#  'Ashley Judd',
#  'Asia',
#  'Asia where',
#  'Asia where Ms',
#  'Asian',
#  'Asian landscape',
#  'Asian landscape painting',
#  'Ask',
#  'Ask still',
#  'Asquith',
#  'Assassin',
#  'Assayas',
#  'Assayas RRB',
#  'Assayas RRB homage',
#  'Association',
#  'Assured',
#  'At',
#  'At its',
#  'At its best',
#  'At its worst',
#  'At once',
#  'At times',
#  'Atlantic',
#  'Atlantic Ocean',
#  'Atlantic Ocean and',
#  'Atlantic love',
#  'Atlantic love him',
#  'Attal',
#  'Attal and',
#  'Attal and Gainsbourg',
#  'Attal hang',
#  'Attal hang ups',
#  'Attraction',
#  'Attraction Weeks',
#  'Audiard',
#  'Audiard though',
#  'Audiard though little',
#  'Audience',
#  'Audience Award',
#  'Audience Award for',
#  'August',
#  'Aurelie',
#  'Aurelie and',
#  'Aurelie and Christelle',
#  'Auschwitz',
#  'Auschwitz II',
#  'Auschwitz II Birkenau',
#  'Austen',
#  'Austin',
#  'Austin Powers',
#  'Austin Powers extravaganza',
#  'Australia',
#  'Australia sweeping',
#  'Australia sweeping and',
#  'Australian',
#  'Austrian',
#  'Austrian society',
#  'Auteil',
#  'Auteil RRB',
#  'Auteuil',
#  'Auto',
#  'Auto Focus',
#  'Avary',
#  'Average',
#  'Avon',
#  'Award',
#  'Award for',
#  'Award for documentaries',
#  'Award winning',
#  'Award winning actor',
#  'Awards',
#  'Away',
#  'Away is',
#  'Awful',
#  'BA',
#  'BA Murdock',
#  'BA Murdock and',
#  'BMW',
#  'Babak',
#  'Babak Payami',
#  'Babak Payami boldly',
#  'Babbitt',
#  'Baby',
#  'Back',
#  'Bacon',
#  'Bacon and',
#  'Bacon and Theron',
#  'Bad',
#  'Bad Company',
#  'Bad Lieutenant',
#  'Bad Love',
#  'Bad News',
#  'Bad News Bears',
#  'Bailly',
#  'Baker',
#  'Bale',
#  'Ball',
#  'Ball and',
#  'Ball and Chain',
#  'Ballistic',
#  'Ballistic Ecks',
#  'Ballistic Ecks vs',
#  'Ballot',
#  'Ballot is',
#  'Balto',
#  'Bambi',
#  'Bambi and',
#  'Bambi and The',
#  'Band',
#  'Banderas',
#  'Banderas Lucy',
#  'Banderas Lucy Liu',
#  'Banger',
#  'Banger Sisters',
#  'Banzai',
#  'Baran',
#  'Barbara',
#  'Barbara sadness',
#  'Barbara sadness and',
#  'Barbera',
#  'Barbera charm',
#  'Barbershop',
#  'Bard',
#  'Bard ending',
#  'Barlow',
#  'Barney',
#  'Barney videos',
#  'Barrels',
#  'Barrels and',
#  'Barris',
#  'Barris motivations',
#  'Barrow',
#  'Barry',
#  'Barry Pepper',
#  'Barry Sonnenfeld',
#  'Barrymore',
#  'Bartleby',
#  'Bartleby pain',
#  'Bartlett',
#  'Bartlett Familiar',
#  'Bartlett Familiar Quotations',
#  'Based',
#  'Based on',
#  'Based on True',
#  'Basketball',
#  'Basketball Association',
#  'Bates',
#  'Battlefield',
#  'Battlefield Earth',
#  'Battlefield Earth and',
#  'Be',
#  'Be Really',
#  'Be Really Awful',
#  'Beach',
#  'Beach boardwalk',
#  'Bean',
#  'Bean abhors',
#  'Beard',
#  'Bears',
#  'Bears should',
#  'Beast',
#  'Beat',
#  'Beautiful',
#  'Beautifully',
#  'Beauty',
#  'Beauty and',
#  'Beauty and the',
#  'Beavis',
#  'Bebe',
#  'Because',
#  'Bedknobs',
#  'Bedknobs and',
#  'Beginners',
#  'Begley',
#  'Begley source',
#  'Begley source novel',
#  'Behan',
#  'Behind',
#  'Behind the',
#  'Behind the Music',
#  'Being',
#  'Being Earnest',
#  'Being Earnest overcome',
#  'Being John',
#  'Being John Malkovich',
#  'Bela',
#  'Bela Lugosi',
#  'Bela Lugosi now',
#  'Belgium',
#  'Ben',
#  'Ben Affleck',
#  'Ben Affleck seem',
#  'Benigni',
#  'Benigni Pinocchio',
#  'Benjamins',
#  'Benshan',
#  'Berg',
#  'Berkley',
#  'Besco',
#  'Besson',
#  'Besson is',
#  'Besson is brand',
#  'Best',
#  'Best Friend',
#  'Best Man',
#  'Bettany',
#  'Bette',
#  'Bette Davis',
#  'Bette Davis cast',
#  'Better',
#  'Betty',
#  'Betty Fisher',
#  'Betty Fisher and',
#  'Bibi',
#  'Bible',
#  'Bible killer',
#  'Bible killer story',
#  'Bible parables',
#  'Bible parables and',
#  'Bickle',
#  'Bielinsky',
#  'Bielinsky great',
#  'Bielinsky great game',
#  'Big',
#  'Big Bad',
#  'Big Bad Love',
#  'Big Chill',
#  'Big Daddy',
#  'Big Fat',
#  'Big Fat Greek',
#  'Big Trouble',
#  'Bigelow',
#  'Bill',
#  'Bill Paxton',
#  'Bill Paxton into',
#  'Billy',
#  'Billy Joe',
#  'Binks',
#  'Binoche',
#  'Birkenau',
#  'Birmingham',
#  'Birot',
#  'Birthday',
#  'Birthday Girl',
#  'Birthday Girl is',
#  'Bisset',
#  'Black',
#  'Black Hawk',
#  'Black Hawk Down',
#  'Black manhood',
#  'Blade',
#  'Blade II',
#  'Blade Runner',
#  'Bladerunner',
#  'Blair',
#  'Blair Witch',
#  'Blair Witch Project',
#  'Blair Witch style',
#  'Blaxploitation',
#  'Blaxploitation films',
#  'Blind',
#  'Blind Date',
#  'Blob',
#  'Blockbuster',
#  'Blockbuster before',
#  'Blockbuster before midnight',
#  'Blonde',
#  'Blonde and',
#  'Blonde and Sweet',
#  'Blood',
#  'Blood Work',
#  'Blue',
#  'Blue Crush',
#  'Boat',
#  'Bob',
#  'Bob Crane',
#  'Bogdanovich',
#  'Bolero',
#  'Bollywood',
#  'Bombay',
#  'Bond',
#  'Bond in',
#  'Bond in Die',
#  'Bond movie',
#  'Bond movie seem',
#  'Bond thriller',
#  'Bond wrestling',
#  'Book',
#  'Boot',
#  'Borg',
#  'Borg Queen',
#  'Borg Queen Alice',
#  'Boston',
#  'Boston Public',
#  'Boston Public just',
#  'Both',
#  'Bourne',
#  'Bourne Identity',
#  'Bourne or',
#  'Bourne or his',
#  'Bow',
#  'Bow Wow',
#  'Bow Wow fans',
#  'Bowling',
#  'Bowling for',
#  'Bowling for Columbine',
#  'Boy',
#  'Boy voice',
#  'Boys',
#  'Branagh',
#  'Braveheart',
#  'Braveheart as',
#  'Braveheart as well',
#  'Bray',
#  'Bread',
#  'Break',
#  'Break Your',
#  'Break Your Heart',
#  'Breaking',
#  'Breaking Out',
#  'Breckin',
#  'Brendan',
#  'Brendan Fraser',
#  'Brian',
#  'Brian De',
#  'Brian De Palma',
#  'Bride',
#  'Bridge',
#  'Bridge is',
#  'Bridget',
#  'Bridget Jones',
#  'Bridget Jones Diary',
#  'Bring',
#  'Bring it',
#  'Bring it On',
#  'Brings',
#  'Brit',
#  'Brit cinema',
#  'British',
#  'British actor',
#  'British actor Ian',
#  'British actor who',
#  'British children',
#  'British children rediscovering',
#  'British comedy',
#  'British comedy circa',
#  'British eccentrics',
#  'British soldiers',
#  'Britney',
#  'Britney Spears',
#  'Britney Spears first',
#  'Britney latest',
#  'Britney latest album',
#  'Brits',
#  'Broadway',
#  'Broadway The',
#  'Broadway The Lion',
#  'Broadway play',
#  'Brockovich',
#  'Broken',
#  'Broken Lizard',
#  'Bronx',
#  'Bronx Tale',
#  'Brooklyn',
#  'Brooklyn stale',
#  'Brooklyn stale cliches',
#  'Brooks',
#  'Broomfield',
#  'Broomfield interviewees',
#  'Broomfield interviewees or',
#  'Brooms',
#  'Broomsticks',
#  'Bros',
#  'Bros costumer',
#  'Bros giant',
#  'Bros giant Chuck',
#  'Brosnan',
#  'Brother',
#  'Brother Man',
#  'Brother Man vs',
#  'Brothers',
#  'Brothers Abrahams',
#  'Brothers Abrahams films',
#  'Brothers and',
#  'Brothers comedy',
#  'Brown',
#  'Brown Sugar',
#  'Brown Sugar is',
#  'Brown celebrated',
#  'Brown celebrated wonder',
#  'Brown snake',
#  'Bruce',
#  'Bruce Willis',
#  'Bruckheimer',
#  'Bruckheimer and',
#  'Bruckheimer and directed',
#  'Bruckheimer elements',
#  'Bruckheimer productions',
#  'Brussels',
#  'Brussels sprouts',
#  'Bryan',
#  'Bryan Adams',
#  'Bubba',
#  'Bubba Ho',
#  'Bubba Ho Tep',
#  'Bubble',
#  'Bubble and',
#  'Bubble and Hugh',
#  'Buckaroo',
#  'Bueller',
#  'Bugsy',
#  'Bugsy than',
#  'Bugsy than the',
#  'Bullock',
#  'Bullock Bubble',
#  'Bullock Bubble and',
#  'Bullock and',
#  'Bullock and Hugh',
#  'Bullock memorable',
#  'Bullock memorable first',
#  'Bullock vehicle',
#  'Bullwinkle',
#  'Burger',
#  'Burkina',
#  'Burkina Faso',
#  'Burning',
#  'Burning Man',
#  'Burning Man ethos',
#  'Burns',
#  'Burns visuals',
#  'Burr',
#  'Burr Steers',
#  'Burr commenting',
#  'Burr commenting on',
#  'Burstein',
#  'Bush',
#  ...]

# %%
"reccomend" in columns
# Out:
# False

# %%
"disappoint" in columns
# Out:
# True

# %%
y_train = train["Sentiment"]

# %%
y_train.
# Out:
#   File "<ipython-input-173-110a9836d71d>", line 1
#     y_train.
#             ^
# SyntaxError: invalid syntax

# %%
X_test = vectorizer.transform(test["Phrase"])
print(X_test.shape)

# %%
from sklearn.linear_model import SGDClassifier
seed = 17
model = SGDClassifier(random_state=seed) # 랜덤 셔플링

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score

predictions = cross_val_predict(model, X_train, y_train, cv = 5)
score = accuracy_score(y_train, predictions)
print(score)

# %%
result = pd.DataFrame({'actual': y_train, 'predict': predictions})
result["distance"] = (result["actual"] - result["predict"]).abs()
result["Phrase"] = train["Phrase"]
result = result.sort_values("distance", ascending= False)
result.head(500).to_csv("Result.csv")
print(result.shape)
result.head()

# %%
result[result["Phrase"].str.contains("recommend")].head

# %%
result[result["Phrase"].str.contains("recommend")]["distance"].mean()

# %%
result[result["Phrase"].str.contains("not funny")]["distance"].mean()

# %%
model.fit (X_train, y_train)

# %%
predictions = model.predict(X_test)

# %%
print(predictions.shape)
predictions[:30]

# %%
submission = pd.read_csv("sampleSubmission.csv", index_col = "PhraseId")
# submission["Sentiment"] = predictions

# %%
submission["Sentiment"] = predictions

# %%
submission.to_csv("first.csv")
